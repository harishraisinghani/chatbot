# %% [markdown]
# # Creating Your Own Basic Chatbot
#
# This tutorial is sourced and adapted from https://medium.com/analytics-vidhya/building-a-simple-chatbot-in-python-using-nltk-7c8c8215ac6e
#
# We will be building a simple **retrieval-based** chatbot, which selects a response from a library of predefined responses based on the context of the conversation. A more intelligent type of chatbot is a **generative** bot which can create answers which are not always from the library.
#
# We will use Python's powerful **scikit** library which contains a Natural Language Toolkit (NLTK) for natural language processing. See https://www.nltk.org/ for more info.

# %% [markdown]
# ### Natural Language Processing (NLP)
#
# NLP is the study of interactions between human language and computers, where computers analyze understand and derive meaning from human lanugage in a smart and useful way.
#
# The overall flow to our NLP exercise today looks like the following:
#
#     1. Identify a *corpus* or body of text data used as the response library
#         For this exercise, we will use the *Memorable Cornell Movie-Quotes Corpus* which is a dataset of over
#         200,000 conversational exchanges between 10,000+ pairs of movie characters! See
#         https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html.
#
#     2. Pre-process this text data which includes:
#          * Converting all the text to *lowercase*
#
#          * Removing movie line numbers
#
#          * Removing all punctuations
#
#          * Removing **stop words** which are extremely common words (such as 'has', 'is', 'of') which would
#          appear to be of little value in helping select the response.
#
#          * Tokenizing the text, which simply means converting the text 'strings' into a list of both individual
#          words and sentences. We will have both *sentence_token* and *word_token* lists.
#
#          * Lemmatization which is reducing a word to its *stem* as well as combining similar words into the same
#          lemma. So for example, "run" is the lemma for words like "running", "runs", or "ran".
#
#     3. Creating a 'Bag of Words'
#         A 'Bag of Words' is a representation of the text which describes the occurrence of words within a
#         document and includes:
#          * A vocabulary of known words
#
#          * A measure of whether the known words occur in the document
#
#         The representation of the text is transformed into a vector (or array) of numbers. So for example, if our
#         vocabulary of known words is: `{Learning, is, the, not, great}` and we want to vectorize the text
#         "Learning is great" then the vector representation of that text is simply: `(1,1,0,0,1)`.
#
#     4. Scaling word frequency
#         We won't get into the mathematical details here, but essentially, a problem with the Bag of Words
#         approach is that highly frequent words start to dominate in the document. One way to address this is to
#         apply a scaling factor to the frequency of words so that higher frequent words are penalized so that they
#         have less weighting, both within a document and across multiple documents. This is done by using the
#         following:
#          * Term Frequency (TF) - a scoring of the frequency of the word in the current document
#          * Inverse Document Frequency (IDF) - a scoring of how rare the word is across multiple documents
#
#         Together, the **TF-IDF** weighting is used to evaluate how important a word is to a document in a
#         collection or corpus.
#
#     5. Calculating similarity
#         The nice thing about converting text into numerical vectors is that you can now use math to calculate how
#         similar (aligned) or disimilar (opposed) the input text is to the text in the vocabulary of known words.
#         Two vectors closely aligned have a cosine of the angle between them close to 1, and when opposed, the
#         cosine is -1.
#
#     6. Identify most similar text vector and send back as response

# %% [markdown]
# ### Chatbot Code
#
# #### Package installations
#
# First, we install the `NLTK` Python library

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.7/site-packages (3.4.5)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from nltk) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then, we import the `nltk` library, along with a few others for data manipulation, and download key `nltk` modules:

# %%
import nltk
import random
import string # to process standard python strings
import re

nltk.download('punkt') # Tokenizer which divides text into a list of sentences using machine learning
nltk.download('wordnet') # A corpus reader to initially read our data
nltk.download('stopwords') # Collection of stop words

from nltk.corpus import stopwords # This is our default list of stopwords
# Out:
# [nltk_data] Downloading package punkt to /Users/newadmin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/newadmin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/newadmin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### Read movie file
#
# Next, take the movie quotes file you downloaded from GitHub, and open it:

# %%
f = open('moviequotes.memorable_quotes.txt', 'r', errors = 'ignore')
raw_data = f.read()

# %%
raw_data
# Out:
# '\n10 things i hate about you\nWho knocked up your sister?\n1181 Who knocked up your sister?\n\n10 things i hate about you\nI was watching you out there, before. I\'ve never seen you look so sexy.\n1115 I watched you out there   I\'ve never seen you look like that\n\n10 things i hate about you\nYou\'re 18, you don\'t know what you want. And you won\'t know what you want \'til you\'re 45, and even if you get it, you\'ll be too old to use it.\n979 You\'re eighteen.  You don\'t know what you want.  You won\'t know until you\'re forty-five and you don\'t have it.\n\n10 things i hate about you\nOoh, see that, there. Who needs affection when I have blind hatred?\n1266 See that?  Who needs affection when I\'ve got blind hatred?\n\n10 things i hate about you\nJust \'cause you\'re beautiful, that doesn\'t mean that you can treat people like they don\'t matter.\n1331 Just because you\'re beautiful, doesn\'t mean you can treat people like they don\'t matter.\n\n10 things i hate about you\nYou\'re asking me out? That\'s so cute! What\'s your name again?\n831 You\'re asking me out.  That\'s so cute. What\'s your name again?\n\n10 things i hate about you\nLeave it to you to use big words when you\'re smashed.\n1258 Leave it to you to use big words when you\'re shitfaced.\n\n10 things i hate about you\nAnd I\'m BACK IN THE GAME!\n1332 And I\'m back in the saddle.\n\n10 things i hate about you\nI guess in this society, being male and an asshole makes you worthy of our time.\n733 I guess the school board thinks because Hemingway\'s male and an asshole, he\'s worthy of our time\n\n10 things i hate about you\nI have a dick on my face, don\'t I?\n876 I have a dick on my face, don\'t I?\n\n10 things i hate about you\nYou embarrassed the girl. Sacrifice yourself on the alter of dignity and even the score.\n1409 You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.\n\n10 things i hate about you\nYou\'re not as vile as I thought you were.\n1322 You know -- you\'re not as vile as I thought you were.\n\n10 things i hate about you\nIt\'s not everyday you find a girl who\'ll flash someone to get you out of detention.\n1667 You know -- it\'s not every day you find a girl who\'ll flash her tits to get you out of detention.\n\n10 things i hate about you\nWatching that bitch violate my car doesn\'t count as a date.\n984 Watching the bitch trash my car doesn\'t count as a date.\n\n10 things i hate about you\nOh wait... was that... did your hairline just recede?\n1184 Wait -- was that?-- Did your hairline just recede?\n\n10 things i hate about you\nRemove head from sphincter, then drive!\n788 Remove head from sphincter!  Then pedal!\n\n1492: conquest of paradise\nOf all the words my father wrote - and there were many - I remember these the most: "Nothing that results from human progress is achieved with unanimous consent. And those who are enlightened before the others are condemned to persue that light in spite of others."\n1697 Of all the words my Father wrote and there were many, I remember these the most.  "Nothing that results from human progress is achieved with unanimous consent..."\n\n15 minutes\nI can kill you - I\'m insane.\n3304 Be careful.  I can kill you.  I\'m insane.\n\n15 minutes\nI love America. No one is responsible for what they do.\n2606 I love America.  No one is responsible for what they do.\n\n2001: a space odyssey\nWelcome to Voiceprint Identification. When you see the red light go on, would you please state in the following order: your destination, your nationality, and your full name; surname first, Christian name and initial.\n3403 Good morning and welcome to voice Print Identification. When you see the red light go on would you please state in the following order; your desitination, your nationality and your full name. Surname first, christian name and initial. For example: Moon, American, Smith, John, D. Thank you.\n\n8mm\nStarlight; star bright, first star I\'ve seen tonight, I wish I may; I wish ...

# %% [markdown]
# See how the `raw_data` object now contains our text from our file. This is our **corpus**.
#
# #### Pre-process movie file
#
# Next, we pre-process our text data and convert them into tokens (i.e. into lists of words and sentences)

# %%
raw_data = raw_data.lower() # Make all letters lowercase
clean_data = re.sub(r"\d+", "", raw_data) # Remove all numbers

clean_data
# Out:
# '\n things i hate about you\nwho knocked up your sister?\n who knocked up your sister?\n\n things i hate about you\ni was watching you out there, before. i\'ve never seen you look so sexy.\n i watched you out there   i\'ve never seen you look like that\n\n things i hate about you\nyou\'re , you don\'t know what you want. and you won\'t know what you want \'til you\'re , and even if you get it, you\'ll be too old to use it.\n you\'re eighteen.  you don\'t know what you want.  you won\'t know until you\'re forty-five and you don\'t have it.\n\n things i hate about you\nooh, see that, there. who needs affection when i have blind hatred?\n see that?  who needs affection when i\'ve got blind hatred?\n\n things i hate about you\njust \'cause you\'re beautiful, that doesn\'t mean that you can treat people like they don\'t matter.\n just because you\'re beautiful, doesn\'t mean you can treat people like they don\'t matter.\n\n things i hate about you\nyou\'re asking me out? that\'s so cute! what\'s your name again?\n you\'re asking me out.  that\'s so cute. what\'s your name again?\n\n things i hate about you\nleave it to you to use big words when you\'re smashed.\n leave it to you to use big words when you\'re shitfaced.\n\n things i hate about you\nand i\'m back in the game!\n and i\'m back in the saddle.\n\n things i hate about you\ni guess in this society, being male and an asshole makes you worthy of our time.\n i guess the school board thinks because hemingway\'s male and an asshole, he\'s worthy of our time\n\n things i hate about you\ni have a dick on my face, don\'t i?\n i have a dick on my face, don\'t i?\n\n things i hate about you\nyou embarrassed the girl. sacrifice yourself on the alter of dignity and even the score.\n you humiliated the woman! sacrifice yourself on the altar of dignity and even the score.\n\n things i hate about you\nyou\'re not as vile as i thought you were.\n you know -- you\'re not as vile as i thought you were.\n\n things i hate about you\nit\'s not everyday you find a girl who\'ll flash someone to get you out of detention.\n you know -- it\'s not every day you find a girl who\'ll flash her tits to get you out of detention.\n\n things i hate about you\nwatching that bitch violate my car doesn\'t count as a date.\n watching the bitch trash my car doesn\'t count as a date.\n\n things i hate about you\noh wait... was that... did your hairline just recede?\n wait -- was that?-- did your hairline just recede?\n\n things i hate about you\nremove head from sphincter, then drive!\n remove head from sphincter!  then pedal!\n\n: conquest of paradise\nof all the words my father wrote - and there were many - i remember these the most: "nothing that results from human progress is achieved with unanimous consent. and those who are enlightened before the others are condemned to persue that light in spite of others."\n of all the words my father wrote and there were many, i remember these the most.  "nothing that results from human progress is achieved with unanimous consent..."\n\n minutes\ni can kill you - i\'m insane.\n be careful.  i can kill you.  i\'m insane.\n\n minutes\ni love america. no one is responsible for what they do.\n i love america.  no one is responsible for what they do.\n\n: a space odyssey\nwelcome to voiceprint identification. when you see the red light go on, would you please state in the following order: your destination, your nationality, and your full name; surname first, christian name and initial.\n good morning and welcome to voice print identification. when you see the red light go on would you please state in the following order; your desitination, your nationality and your full name. surname first, christian name and initial. for example: moon, american, smith, john, d. thank you.\n\nmm\nstarlight; star bright, first star i\'ve seen tonight, i wish i may; i wish i might, have this wish i wish tonight\n "star light, star bright, first star i\'ve seen tonight, wish i may, wish i might ...

# %% [markdown]
# Now we have some cleaner text data to work with. We will remove the punctuation in a bit.
#
# #### Tokenize our text
#
# Next, we tokenize our text data into words and sentences:

# %%
sent_tokens = nltk.sent_tokenize(clean_data)# converts to list of sentences 
word_tokens = nltk.word_tokenize(clean_data)# converts to list of words

# %%
sent_tokens
# Out:
# ['\n things i hate about you\nwho knocked up your sister?',
#  'who knocked up your sister?',
#  'things i hate about you\ni was watching you out there, before.',
#  "i've never seen you look so sexy.",
#  "i watched you out there   i've never seen you look like that\n\n things i hate about you\nyou're , you don't know what you want.",
#  "and you won't know what you want 'til you're , and even if you get it, you'll be too old to use it.",
#  "you're eighteen.",
#  "you don't know what you want.",
#  "you won't know until you're forty-five and you don't have it.",
#  'things i hate about you\nooh, see that, there.',
#  'who needs affection when i have blind hatred?',
#  'see that?',
#  "who needs affection when i've got blind hatred?",
#  "things i hate about you\njust 'cause you're beautiful, that doesn't mean that you can treat people like they don't matter.",
#  "just because you're beautiful, doesn't mean you can treat people like they don't matter.",
#  "things i hate about you\nyou're asking me out?",
#  "that's so cute!",
#  "what's your name again?",
#  "you're asking me out.",
#  "that's so cute.",
#  "what's your name again?",
#  "things i hate about you\nleave it to you to use big words when you're smashed.",
#  "leave it to you to use big words when you're shitfaced.",
#  "things i hate about you\nand i'm back in the game!",
#  "and i'm back in the saddle.",
#  'things i hate about you\ni guess in this society, being male and an asshole makes you worthy of our time.',
#  "i guess the school board thinks because hemingway's male and an asshole, he's worthy of our time\n\n things i hate about you\ni have a dick on my face, don't i?",
#  "i have a dick on my face, don't i?",
#  'things i hate about you\nyou embarrassed the girl.',
#  'sacrifice yourself on the alter of dignity and even the score.',
#  'you humiliated the woman!',
#  'sacrifice yourself on the altar of dignity and even the score.',
#  "things i hate about you\nyou're not as vile as i thought you were.",
#  "you know -- you're not as vile as i thought you were.",
#  "things i hate about you\nit's not everyday you find a girl who'll flash someone to get you out of detention.",
#  "you know -- it's not every day you find a girl who'll flash her tits to get you out of detention.",
#  "things i hate about you\nwatching that bitch violate my car doesn't count as a date.",
#  "watching the bitch trash my car doesn't count as a date.",
#  'things i hate about you\noh wait... was that... did your hairline just recede?',
#  'wait -- was that?-- did your hairline just recede?',
#  'things i hate about you\nremove head from sphincter, then drive!',
#  'remove head from sphincter!',
#  'then pedal!',
#  ': conquest of paradise\nof all the words my father wrote - and there were many - i remember these the most: "nothing that results from human progress is achieved with unanimous consent.',
#  'and those who are enlightened before the others are condemned to persue that light in spite of others."',
#  'of all the words my father wrote and there were many, i remember these the most.',
#  '"nothing that results from human progress is achieved with unanimous consent..."\n\n minutes\ni can kill you - i\'m insane.',
#  'be careful.',
#  'i can kill you.',
#  "i'm insane.",
#  'minutes\ni love america.',
#  'no one is responsible for what they do.',
#  'i love america.',
#  'no one is responsible for what they do.',
#  ': a space odyssey\nwelcome to voiceprint identification.',
#  'when you see the red light go on, would you please state in the following order: your destination, your nationality, and your full name; surname first, christian name and initial.',
#  'good morning and welcome to voice print identification.',
#  'when you see the red light go on would you please state in the following order; your desitination, your nationality and your full name.',
#  'surname first, christian name and initial.',
#  'for example: moon, american, smith, john, d. thank you.',
#  'mm\nstarlight; star bright, first star i\'ve seen tonight, i wish i may; i wish i might, have this wish i wish tonight\n "star light, star bright, first star i\'ve seen tonight, wish i may, wish i might, have this wish i wish tonight."',
#  "mm\noh, he's a lover, man... definitely loves what he does for a living.",
#  "he's a brutal motherfucker, man.",
#  'he loves what he does for a living.',
#  "a bucket of blood\ni didn't mean to hurt you, lou.",
#  "but if you'd have shot me, you'd be moppin' up my blood now.",
#  "i didn't mean to hurt you, sir... if you had shot me, you'd be mopping up my blood now...\n\na bucket of blood\nwhere are john, joe, jake, jim, jerk?",
#  'dead, dead, dead!',
#  'they were not born, before they were born, they were not born.',
#  'where are leonardo, rembrandt, ludwig?',
#  'alive!',
#  'alive!',
#  'alive!',
#  'they were born!',
#  'where are john joe jake jim jerk, dead dead dead, they were not born before they were born, they were not born, where are leonardo, mozart, shakespeare, alive alive alive, they were born -\n\na bucket of blood\nwalter has a clear mind.',
#  'one day something will enter it, feel lonely... and leave again.',
#  "walter's got a clear mind.",
#  'probably something will enter it, feel lonely, and leave again...\n\na bucket of blood\nring rubber bells!',
#  'beat cotton gongs!',
#  'strike silken cymbals!',
#  'ring rubber bells, beat cotton gongs, strike silken cymbals...\n\na clockwork orange\none thing i could never stand was to see a filthy, dirty old drunkie, howling away at the filthy songs of his fathers and going blurp blurp in between as it might be a filthy old orchestra in his stinking, rotten guts.',
#  'i could never stand to see anyone like that, whatever his age might be, but more especially when he was real old like this one was.',
#  'one thing i could never stand is to see a filthy, dirty old drunkie, howling away at the filthy songs of his fathers and going blerp, blerp in between as it might be a filthy old orchestra in his stinking rotten guts.',
#  'i could never stand to see anyone like that, whatever his age might be, but more especially when he was real old like this one was.',
#  'the boys stop and applaud him.',
#  'a clockwork orange\nshe was very badly raped, you see!',
#  'we were assaulted by a gang of vicious, young, hoodlums in this house!',
#  'in this very room you are sitting in now!',
#  'i was left a helpless cripple, but for her the agony was too great!',
#  'the doctor said it was pneumonia; because it happened some months later!',
#  'during a flu epidemic!',
#  'the doctors told me it was pneumonia, but i knew what it was!',
#  'a victim of the modern age!',
#  'poor, poor girl!',
#  'she was very badly raped, you see.',
#  "we were assaulted by a gang of vicious young hooligans in this house, in this very room you're sitting in now.",
#  'i was left a helpless cripple.',
#  "the doctors said it was pneumonia, because it happened some months later during the 'flu epidemic.",
#  'the doctors told me it was pneumonia, but i knew what it was.',
#  'a victim of the modern age, poor, poor girl.',
#  'suddenly his mood changes.',
#  'he wheels right up to alex.',
#  'a clockwork orange\ni jumped, o my brothers, and i fell hard but i did not snuff it, oh no.',
#  'if i had snuffed it, i would not be here to tell what i have told.',
#  'i jumped, o my brothers, and i fell hard but i did not snuff it, oh no.',
#  'if i had snuffed it, i would not be here to tell what i have told.',
#  'i came back to life, after a long, black, black gap of what might have been a million years.',
#  'we hear alex moan, and then another moan.',
#  'alex and the other - a few times.',
#  'suddenly, some curtains which have been drawn around another bed in the ward are parted, and a nurse hurries to alex, hastily buttoning up her uniform.',
#  'she is trailed by a young intern fumbling with his trousers.',
#  'a clockwork orange\nappy-polly-loggies.',
#  'i had something of a pain in the gulliver so had to sleep.',
#  'i was not awakened when i gave orders for wakening.',
#  'appy polly loggies.',
#  'i had something of a pain in the gulliver so had to sleep.',
#  'i was not awakened when i gave orders for awakening.',
#  "a clockwork orange\nenjoying that are you my darlin'?",
#  "bit cold and pointless isn't it my lovely?",
#  "what's happened to yours my little sister?",
#  'enjoying it then, my darling?...',
#  "a bit cold and pointless isn't it, my lovely... what's happened to yours, my little sister?",
#  'marty giggles.',
#  "a clockwork orange\ni've suffered the tortures of the damned, sir  - tortures of the damned.",
#  "i've suffered the tortures of the damned.",
#  'the tortures of the damned, sir.',
#  'a clockwork orange\nwelly, welly, welly, welly, welly, welly, well.',
#  'to what do i owe the extreme pleasure of this surprising visit?',
#  'welly, welly, welly, welly, welly, welly, well.',
#  'to what do i owe the extreme pleasure of this surprising visit?',
#  'georgie rises.',
#  'a clockwork orange\nviddy well, little brother.',
#  'viddy well.',
#  'viddy well, my little brother.',
#  'viddy well.',
#  "a clockwork orange\nwell, like he says, it's mostly odd things he does.",
#  'helping like... here and there as it might be.',
#  "well, like he says, it's mostly odd things he does, helping like... here and there, as it might be.",
#  'a clockwork orange\npick that up and put it down properly!',
#  'pick that up and put it down properly.',
#  'alex does so, and continues to empty his pockets.',
#  'a clockwork orange\nare you now, or have you ever been a homosexual?',
#  'are you now, or ever have been, a homosexual?',
#  'a clockwork orange\nwhat you got back home, little sister, to play your fuzzy warbles on?',
#  'i bet you got little save pitiful, portable picnic players.',
#  'come with uncle and hear all proper!',
#  'hear angel trumpets and devil trombones.',
#  'you are invited.',
#  'what you got back home, little sister, to play your fuzzy warbles on?',
#  'i bet you got little save pitiful portable picnic players.',
#  'come with uncle and hear all proper.',
#  'hear angel trumpets and devil trombones.',
#  'you are invited.',
#  'a clockwork orange\nhi, hi, hi there!',
#  'at last we meet.',
#  'our brief govoreet through the letter-hole was not, shall we say, satisfactory, yes?',
#  'our brief govereet thru the letter hole was not, shall we say, satisfactory, yes?',
#  'a clockwork orange\nas we walked along the flatblock marina, i was calm on the outside, but thinking all the time - now it was to be georgie the general, saying what we should do and what not to do, and dim as his mindless greeding bulldog.',
#  'but suddenly, i viddied that thinking was for the gloopy ones, and that the oomny ones use like, inspiration and what bog sends.',
#  'now it was lovely music that came into my aid.',
#  'there was a window open with the stereo on, and i viddied right at once what to do.',
#  'as we walked along the flatblock marina, i was calm on the outside but thinking all the time, so now it was to be georgie the general, saying what we should do and what not to do, and dim as his mindless, grinning bulldog.',
#  'but, suddenly, i viddied that thinking was for the gloopy ones and that the oomny ones use like inspiration and what bog sends, for now it was lovely music that came to my aid and i viddied at once what to do.',
#  'there was a window open with the stereo on.',
#  'a clockwork orange\nit had been a wonderful evening and what i needed now, to give it the perfect ending, was a little of the ludwig van.',
#  'it had been a wonderful evening and what i needed now to give it the perfect ending was a bit of the old ludwig van.',
#  'music starts.',
#  'a clockwork orange\ni woke up.',
#  'the pain and sickness all over me like an animal.',
#  'then i realized what it was.',
#  'the music coming up from the floor was our old friend, ludwig van, and the dreaded ninth symphony.',
#  'i woke up.',
#  'the pain and sickness all over me like an animal.',
#  'then i realised what it was.',
#  'the music coming up from the floor was our old friend, ludwig van and the dreaded th symphony.',
#  'he staggers to the door.',
#  'it is locked.',
#  'he kicks and tugs the door.',
#  'a clockwork orange\nshut your filthy hole, you scum!',
#  'shut your filthy hole, you scum!!!',
#  'a clockwork orange\nnaughty, naughty, naughty!',
#  'you filthy old soomka!',
#  'naughty, naughty, naughty, you filthy old soomaka.',
#  'a clockwork orange\nexcuse me, mrs. can you please help?',
#  "there's been a terrible accident!",
#  "my friend's in the middle of the road bleeding to death!",
#  'can i please use your telephone for an ambulance?',
#  'excuse me, missus, can you please help?',
#  "there's been a terrible accident.",
#  'can i please use your telephone for an ambulance?',
#  'a clockwork orange\neggiwegs!',
#  'i would like... to smash them!',
#  'eggiwegs.',
#  "i would like to smash 'em.",
#  'pick up th elot and f... owww... he slams his hand down and cries out with pain.',
#  'a clockwork orange\nho, ho, ho!',
#  "well, if it isn't fat stinking billy goat billy boy in poison!",
#  'how art thou, thou globby bottle of cheap, stinking chip oil?',
#  'come and get one in the yarbles, if ya have any yarbles, you eunuch jelly thou!',
#  "ho, ho, ho... well, if it isn't stinking billygoat billyboy in poison.",
#  'how are thou, thou globby bottle of cheap stinking chip oil?',
#  'come and get one in the yarbles, if you have any yarbles, you eunuch jelly thou.',
#  'billyboy snaps open a switchblade knife.',
#  "a clockwork orange\nthe durango ' purred away a real horrowshow - a nice, warm vibraty feeling all through your guttiwuts.",
#  'and soon it was trees and dark, my brothers, with real country dark.',
#  'the durango- purred away real horrorshow - a nice, warm vibraty feeling all through your guttiwuts.',
#  'soon it was trees and dark, my brothers, with real country dark.',
#  'we fillied around for a while with other travelers of the night, playing hogs of the road.',
#  'then we headed west, what we were after now was the old surprise visit, that was a real kick and good for laughs and lashing of the ultra-violent.',
#  'a clockwork orange\nthere was me, that is alex, and my three droogs, that is pete, georgie, and dim, and we sat in the korova milkbar trying to make up our rassoodocks what to do with the evening.',
#  'the korova milkbar sold milk-plus, milk plus vellocet or synthemesc or drencrom, which is what we were drinking.',
#  'this would sharpen you up and make you ready for a bit of the old ultra-violence.',
#  'there was me, that is alex, and my three droogs, that is pete, georgie and dim and we sat in the korova milkbar trying to make up our rassoodocks what to do with the evening.',
#  'the korova milk bar sold milkplus, milk plus vellocet or synthemesc or drencrom which is what we were drinking.',
#  'this would sharpen you up and make you ready for a bit of the old ultra-violence.',
#  "our pockets were full of money so there was no need on that score, but, as they say, money isn't everything.",
#  'a clockwork orange\nsuddenly, i viddied what i had to do, and what i had wanted to do, and that was to do myself in; to snuff it, to blast off for ever out of this wicked, cruel world.',
#  'one moment of pain perhaps and, then, sleep for ever, and ever and ever.',
#  'suddenly i viddied what i had to do, and what i had wanted to do - and that was to do myself in, to snuff it, to blast off forever out of this wicked cruel world.',
#  'one moment of pain perhaps and then sleep - forever and ever and ever.',
#  'a few good men\n"i strenuously object?"',
#  'is that how it works?',
#  'hm?',
#  '"objection."',
#  '"overruled."',
#  '"oh, no, no, no.',
#  'no, i strenuously object."',
#  '"oh.',
#  'well, if you strenuously object then i should take some time to reconsider."',
#  'i strenuously object?',
#  'is that how it works?',
#  'objection.',
#  'overruled.',
#  'no, no, no, no, i strenuously object.',
#  'oh, well if you strenuously object, let me take a moment to reconsider.',
#  'a few good men\nwe joined the marines because we wanted to live our lives by a certain code, and we found it in the corps.',
#  "now you're asking us to sign a piece of paper that says we have no honor.",
#  "you're asking us to say we're not marines.",
#  "if a court decides that what we did was wrong, then i'll accept whatever punishment they give.",
#  'but i believe i was right sir, i believe i did my job, and i will not dishonor myself, my unit, or the corps so i can go home in six months... sir.',
#  'what do we do then, sir?',
#  "we joined the corps 'cause we wanted to live our lives by a certain code.",
#  'and we found it in the corps.',
#  "and now you're asking us to sign a piece of paper that says we have no honor.",
#  "you're asking us to say we're not marines.",
#  "if a judge and jury decide that what we did was wrong, i'll accept whatever punishment they give.",
#  'but i believe i was riqht, sir.',
#  'i believe i did my job.',
#  "and i won't dishonor myself, my unit, or the corps, so that i can qo home in six months.",
#  'sir.',
#  "a few good men\nwhy does a lieutenant junior grade with nine months' experience and a track record for plea bargaining get assigned to a murder case?",
#  'would it be so it never sees the inside of a courtroom?',
#  'why does a junior grade with six months experience and a track record for plea bargaining get assigned a murder case?',
#  'would it be so that it never sees the inside of a courtroom?',
#  "a few good men\nis the colonel's underwear a matter of national security?",
#  "is the colonel's underwear a matter of national security?",
#  'a few good men\nyou see danny, i can deal with the bullets, and the bombs, and the blood.',
#  "i don't want money, and i don't want medals.",
#  'what i do want is for you to stand there in that faggoty white uniform and with your harvard mouth extend me some fucking courtesy.',
#  'you gotta ask me nicely.',
#  'you have to ask me nicely.',
#  'you see, danny, i can deal with the bullets and the bombs and the blood.',
#  'i can deal with the heat and the stress and the fear.',
#  "i don't want money and i don't want medals.",
#  "what i want is for you to stand there in that faggoty white uniform, and with your harvard mouth, extend me some fuckin' courtesy.",
#  'you gotta ask me nicely.',
#  'a few good men\ntake caution in your tone, commander.',
#  "i'm a fair guy, but this fucking heat is making me absolutely crazy.",
#  'take caution in your tone, commander.',
#  "i'm a fair guy, but this fuckin' heat's making me absolutely crazy.",
#  'you want to know about code reds?',
#  'on the record i tell you that i discourage the practice in accordance with the nis directive.',
#  "off the record i tell you that it's an invaluable part of close infantry training, and if it happens to go on without my knowledge, so be it.",
#  'i run my base how i run my base.',
#  'you want to investigate me, roll the dice and take your chances.',
#  'i eat breakfast  yards away from  cubans who are trained to kill me.',
#  "so don't for one second think you're gonna come down here, flash a badge, and make me nervous.",
#  'a few good men\noh, spare me the psychobabble father bullshit.',
#  'please, spare me the psycho-babble father bullshit.',
#  "dawson and downey'll have their day in court, but they'll have it with another lawyer.",
#  "a few good men\noh, hah, i'm sorry, i keep forgetting.",
#  'you were sick the day they taught law at law school.',
#  'ah, i keep forgetting: you were sick the day they taught law at law school.',
#  'a few good men\nso this is what a courtroom looks like.',
#  'so this is what a courtroom looks like.',
#  'a few good men\nwhat do you wanna discuss now?',
#  'my favorite color?',
#  'what would you like to discuss now!',
#  'my favorite color?',
#  "a few good men\noh, now i see what you're saying.",
#  'it had to be professor plum in the library with the candlestick.',
#  "oh, now i see what you're saying.",
#  'it had to be professor plum in the library with the candlestick.',
#  'a few good men\nmaybe, if we work at it, we can get dawson charged with the kennedy assassination.',
#  'maybe if we work at it we can get dawson charged with the kennedy assassination.',
#  'a few good men\nwhatever happened to saluting an officer when he leaves the room?',
#  'what happened to saluting an officer when he leaves the room?',
#  "a hard day's night\nyou don't know what this means to me.",
#  "if you hadn't come back it would have meant... the epilogue or the news... in welsh... for life!",
#  "boys, you don't know what this means to me.",
#  "if you hadn't come back it would have been the epilogue or the news in welsh for life.",
#  "a hard day's night\nhe's sex obsessed!",
#  "the older generation's leading our nation in a state of galloping ruin!",
#  "he's sex-obsessed, the older generation are leading this country to galloping ruin.",
#  "a hard day's night\ngod knows what you've unleashed on the unsuspecting south.",
#  "it'll be wine, women, and song all the way with ringo when he gets the taste for it.",
#  "god knows what you've unleashed on the unsuspecting south.",
#  "it'll be wine, women and song all the way with ringo once he's got the taste for it.",
#  "a hard day's night\nhe's very fussy about his drums, you know.",
#  'they loom large in his legend.',
#  "he's very touchy about those his drums, they loom large in his legend.",
#  "a hard day's night\nhey, you won't interfere with the basic rugged concept of me personality, will you madam?",
#  "you won't interfere with the basic rugged concept of my personality, will you, girl?",
#  "a hard day's night\ni'm going out parading before it's too late!",
#  "i'm going parading before it's too late!",
#  "a hard day's night\nthere you go, hiding behind a smokescreen of bourgeois cliches.",
#  "that's right retreat behind a smoke screen of bourgeois cliches.",
#  "i don't go round messing about with your ear-phones, do i?",
#  "a hard day's night\nsorry we hurt your field, mister.",
#  'sorry if we hurt your field, mister.',
#  "a hard day's night\nget me a bottle of milk and some tranquilizers.",
#  "i see it all now, it's a plot... a plot...\n give me a bottle of milk and a packet of oblivion.",
#  "oh, it's a plot, i see it now, it's all a plot.",
#  "a hard day's night\ni now declare this bridge open!",
#  'i now declare this bridge open.',
#  "a nightmare on elm street\none, two, freddy's coming for you.",
#  '/ three, four, better lock your door.',
#  '/ five, six, grab your crucifix.',
#  '/ seven, eight, gonna stay up late.',
#  '/ nine, ten, never sleep again.',
#  "one, two, freddie's coming for you, three four, better lock your door, five six, grab your crucifix, seven eight gonna stay up late, nine ten, never sleep again...\n\na nightmare on elm street\ni'm going to punch out your ugly lights, whoever you are!",
#  "i'm gonna punch out your ugly lights, whoever you are.",
#  "a nightmare on elm street\ni don't know what's real anymore.",
#  "i don't know who he is.",
#  "but he's burned, he wears a weird hat, a red and yellow sweater, real dirty, and he uses some sort of knifes he's got made into a sort of... glove.",
#  'like giant fingernails.',
#  'a nightmare on elm street\nguys can have nightmares too ya know.',
#  "ya ain't got a corner on the market or somethin'.",
#  "guys can have nightmares too, y'know.",
#  "you ain't got a corner on the fucking market or something.",
#  "a nightmare on elm street\nmaybe we're gonna have a big earthquake.",
#  'they say things get really weird just before.',
#  "maybe we're gonna have the big earthquake.",
#  'they say things get weird just before that...\n\na nightmare on elm street\ntina, you either gotta cut your fingernails or ya gotta stop that kind of dreaming.',
#  'one or the other.',
#  'hold your horses.',
#  'you gotta cut your nails or stop that kind of dreaming, tina.',
#  'one or the other.',
#  'a nightmare on elm street\nokay krueger, we play in your court.',
#  'okay, krueger, you bastard.',
#  'we play in your court.',
#  'a nightmare on elm street\nand now i lay me down to sleep, i pray the lord my soul to keep.',
#  'and if i die before i wake, i pray the lord my soul to take.',
#  'now i lay me down to sleep, i pray the lord my soul to keep.',
#  'if i should die before i wake, i pray the lord my soul to take.',
#  'a nightmare on elm street\noh, god, i could be bounded in a nutshell, and count myself a king of infinite space, were it not that i have bad dreams.',
#  "o god, i could be bounded in a nutshell and count myself a king of infinite space, were it not that i have bad dreams...\n\na nightmare on elm street\nwhatever you do don't fall asleep.",
#  "meanwhile whatever you do don't fall asleep.",
#  'midnight.',
#  "a nightmare on elm street\ni'm your boyfriend now, nancy.",
#  "i'm your boyfriend now...\n\na nightmare on elm street\noh, man.",
#  'midnight.',
#  'baseball bats and boogeymen.',
#  'beautiful.',
#  'holy shit!',
#  'midnight.',
#  'baseball bats and boogemen.',
#  'unfucking real.',
#  "a nightmare on elm street\ni probably could have saved her if i'd have moved sooner.",
#  'but i thought it was just another nightmare, like the one i had the night before.',
#  'there was... there was this guy; he had knives for fingers.',
#  "i probably could've saved her if i'd moved sooner... but i thought it was just another nightmare, like the one i had the night before.",
#  'there... was this guy who had knives for fingers...\n\na nightmare on elm street\nnancy, you dreamed about the same creep i did.',
#  'nancy.',
#  'you dreamed about the same creep i did, nancy...\n\na nightmare on elm street\nyou gotta believe in something, right?',
#  "i'm gonna be here when you wake up.",
#  "you're gonna make it.",
#  'i believe in you, me, and rock and roll.',
#  "and i'm not too sure about you lately.",
#  "a nightmare on elm street : dream warriors\nain't gonna dream no more, no more.",
#  "ain't gonna dream no more.",
#  'all night long i sing this song.',
#  "ain't gonna dream no more.",
#  "i ain't gonna dream no more, no more, i ain't gonna dream no more.",
#  "all night long i sing this song, 'cause i ain't gonna dream no more...\n\na nightmare on elm street : dream warriors\ndo you like my body, joey?",
#  'do you like my body, joey?',
#  "a nightmare on elm street : dream warriors\nif your only faith is science, doctor, it may be you that's laid to rest.",
#  "if your only faith is science, doctor... it may be you that's laid to rest.",
#  'a nightmare on elm street : dream warriors\nthis is where he takes us.',
#  'this is where he takes us.',
#  'a nightmare on elm street : dream warriors\nphillip, wake up... have a nice stroll, asshole.',
#  'have a nice stroll, asshole.',
#  "a nightmare on elm street : dream warriors\nlet's snuff the sucka.",
#  "let's snuff the fucker.",
#  'a nightmare on elm street : dream warriors\nhi.',
#  'welcome to the snake pit.',
#  'hi.',
#  'welcome to the snake pit.',
#  'a nightmare on elm street : dream warriors\nin my dreams i can walk.',
#  'my legs are strong.',
#  'in my dreams i am the wizard master.',
#  'in my dreams, i can walk.',
#  'my legs are strong.',
#  "a nightmare on elm street : dream warriors\nyou stupid bitch, you're killing us... you're killing us.",
#  'you stupid bitch!',
#  "you're killing us!",
#  'killing us!',
#  "a nightmare on elm street : dream warriors\nit's now or never.",
#  "i'm not gonna kid you, this is as dangerous as it gets.",
#  "if you die in this dream it's for real.",
#  "nobody has to go in that doesn't want to.",
#  "it's now or never.",
#  "i won't kid you.",
#  'this is as dangerous as it gets.',
#  "if you die in the dream, it's for real.",
#  "nobody has to go in that doesn't want to.",
#  'a nightmare on elm street : dream warriors\nmy god.',
#  'you were his mother.',
#  'my god.',
#  'you were his mother.',
#  'a nightmare on elm street : the dream master\ni wanna draw some blood!',
#  "i need to draw some blood...\n\na nightmare on elm street : the dream master\nyou can check in, but you can't check out.",
#  "you can check in, but you can't check out!",
#  'a nightmare on elm street : the dream master\nwelcome to wonderland, alice.',
#  'welcome to wonderland, alice!',
#  'hahahaha!',
#  "a nightmare on elm street : the dream master\nyou shouldn't have buried me.",
#  "i'm not dead.",
#  "you shouldn't've buried me...i'm not dead.",
#  "a nightmare on elm street : the dream master\nthis ain't my dreamland.",
#  'kristen!',
#  "if you're here, i'm gonna pound your ass!",
#  "this ain't my dreamland.",
#  'kristen.',
#  "if you here i'm gonna pound your ass!!",
#  'a nightmare on elm street : the dream master\na true warrior needs no eyes.',
#  'a true warrior, rick-san, needs no eyes.',
#  "a nightmare on elm street : the dream master\nif the food don't kill ya, the service will.",
#  "if the food don't kill ya, the service will, hahaha!",
#  'a nightmare on elm street : the dream master\nninja warriors have calm.',
#  'find your balance, rick!',
#  'ninja warriors have calm.',
#  'find your balance, rick.',
#  "a nightmare on elm street : the dream master\nyou think you've got what it takes?",
#  "i've been guarding my gate for a long time, bitch.",
#  'you think you got what it takes, i been guarding my gate forever, hahaha!',
#  'a nightmare on elm street : the dream master\noh, hi, handsome.',
#  'care for some buns?',
#  'hi, handsome.',
#  'care for some buns?',
#  'a nightmare on elm street : the dream master\nall the towns in america, and i gotta move to the bermuda triangle.',
#  "that's great.",
#  'all the towns in america, i had to move to the bermuda triangle.',
#  'a nightmare on elm street : the dream master\njoey!',
#  'kincaid!',
#  'help me!',
#  'joey!',
#  'kincaid!',
#  'a nightmare on elm street : the dream master\nhow sweet.',
#  'fresh meat.',
#  'how sweet!',
#  'fresh meat!',
#  "a nightmare on elm street : the dream master\nhow's this for a wet dream?",
#  "how's this for a wet dream?",
#  "a nightmare on elm street : the dream master\nall right, i'm gonna punch his ticket in.",
#  "alright, asleep or awake, i'm gonna punch his ticket in.",
#  "a nightmare on elm street part : freddy's revenge\ngo ahead, jesse.",
#  'try it on for size.',
#  'go ahead, jesse.',
#  'try it on for size!',
#  "a nightmare on elm street part : freddy's revenge\nfight him.",
#  'you are not afraid of him!',
#  "he doesn't even exist!",
#  "you're not afraid of him!",
#  "he doesn't even exist.",
#  "a nightmare on elm street part : freddy's revenge\nhe can't fight me.",
#  "i'm him.",
#  "he can't fight me.",
#  "i'm him.",
#  "a nightmare on elm street part : freddy's revenge\nthen what is it?",
#  'bird rabies?',
#  "it's that cheap seed you been buying.",
#  'alright then, what is it?',
#  'bird rabies?',
#  "that cheap seed you've been buying?",
#  "a nightmare on elm street part : freddy's revenge\nschneider got wasted last night.",
#  'he must have been working late.',
#  'some maniac sliced him up like a kielbasa, hacked him in the shower.',
#  'got bloody footprints all over the place.',
#  "he must've been working late and some fruitcake came in and sliced him up like a kielbasa.",
#  'in the shower!',
#  "left bloody footprints all over the...\n\na nightmare on elm street part : freddy's revenge\nif you want to play with animals, mr. walsh, join the circus.",
#  'if you want to play with animals, mr. walsh, join the circus.',
#  "a nightmare on elm street part : freddy's revenge\nkill me, lisa.",
#  'please kill me... i love you, lisa.',
#  'kill me!',
#  'please kill me!',
#  "a nightmare on elm street part : freddy's revenge\nwake up, little girl.",
#  "wake up, little girl...\n\na nightmare on elm street part : freddy's revenge\nokay, i believe you.",
#  "you've had some scary dreams okay?",
#  'i believe you.',
#  'you had some scary dreams, okay?',
#  "a nightmare on elm street part : freddy's revenge\nmommy?",
#  "why can't jesse wake up like everybody else?",
#  "why can't jesse wake up like every- body else?",
#  "a nightmare on elm street: the dream child\nwhy don't you shut up and let her talk?",
#  'i mean two of us have died in the past two days.',
#  'does that just strike you as particularly normal?',
#  "why don't you shut up and let her talk!",
#  'two of us died in the last two days, does that strike you as particularly normal?!',
#  'a nightmare on elm street: the dream child\n... seven, eight, better stay awake.',
#  "nine, ten, he's back again.",
#  "nine ten, freddy's back again...\n\na nightmare on elm street: the dream child\nall right, krueger... this time it's for keeps!",
#  'all right, krueger.',
#  "this time it's for keeps.",
#  'a nightmare on elm street: the dream child\nhey, danny, better not dream and drive.',
#  "don't dream and drive!",
#  'a nightmare on elm street: the dream child\nnothing but the best for greta!',
#  'nothing but the best for greta!',
#  'a nightmare on elm street: the dream child\nkids... always a disappointment.',
#  'kids!',
#  'always a disappointment.',
#  'a nightmare on elm street: the dream child\nyee-haw!',
#  'this boy feels the need for speed.',
#  'time to feel the need for speed, dickweed!',
#  'a perfect world\nyou know, phillip, you have a goddamned red, white and blue american right to eat cotton candy and ride roller coasters.',
#  'you know, phillip, you have a goddammed red, white and blue american right to eat cotton candy and ride roller coasters.',
#  "a perfect world\nyou're a fucking crazy man.",
#  "yer' a fuckin' crazy man.",
#  "a perfect world\ni need me a time machine with a loud radio to take me where i'm going.",
#  "naw, phillip, i need me a time machine with a loud radio to take me where i'm goin'.",
#  "walkin's for squares.",
#  'a serious man\nsy ableman was a serious man.',
#  'sy ableman was a serious man!',
#  "a serious man\ni feel like the carpet's been yanked out from under me.",
#  "i feel like the carpet's been yanked out from under me.",
#  "i don't know which end is up.",
#  "i'm not even sure how to react; i'm too confused.",
#  'rabbi scott what reasons did she give?',
#  'for the rupture?',
#  "a serious man\ni don't want santana abraxis!",
#  "i've just been in a terrible auto accident!",
#  'look, something is very wrong!',
#  "i don't want santana abraxis!",
#  "i've just been in a terrible auto accident!",
#  'beat.',
#  "a walk to remember\nour love is like the wind... i can't see it, but i sure can feel it.",
#  "it's like the wind.",
#  "i can't see it but i feel it.",
#  "a walk to remember\nall i know is... you're beautiful.",
#  "'yes.",
#  "you're beautiful.'",
#  'above the law\nthis maniac should be wearing a number, not a badge.',
#  'that maniac should be wearing a number, not a badge.',
#  'absolute power\nthis person, they... they go in the front door, then they go out a window and down a rope in the middle of the night?',
#  "if i could do something like that, i'd be the star of my a.a.r.p.",
#  'meetings.',
#  'i wish it was true.',
#  'your robber actually went in the front door but came out down a rope in the dark in the middle of the night?',
#  "if only i could do stuff like that -- i'd be the star of my a.a.r.p.",
#  'meetings.',
#  'absolute power\nyour life could be a whole lot simpler if you could learn to operate a vcr.',
#  'luther.',
#  'your life would be a whole lot simpler if you could learn to operate a v.c.r.',
#  "absolute power\ndo you know what it's like to be the only kid in the first grade who got to talk about visiting day?",
#  "-- you know what it's like being the only kid in show and tell who got to talk about visiting day?",
#  "absolute power\nkate, he's on the run and he's scared.",
#  "and he's right to be scared, 'cause he's gonna get caught.",
#  "you don't know the heat on this.",
#  "kate, he's on the run and he's scared and he's right to be scared because he's going to get caught -- you don't know the heat on this.",
#  'absolute power\nremember, tomorrow is promised to no one.',
#  'tomorrow is promised to no one.',
#  "absolute power\ni'm your substitute driver tonight, mr. sullivan.",
#  "you don't need an appointment, mr. sullivan.",
#  "absolute power\nyou work with your hands, don't you?",
#  "you work with your hands, don't you?",
#  "absolute power\ni'd been married to my rebecca for forty-seven years.",
#  'when she died, i decided i never wanted that pain again.',
#  'one thing i knew about christy, she was going to outlive me.',
#  "i'd been married to my rebecca for forty-seven years and when she died, i decided i never wanted that pain again.",
#  'one thing i knew about christy: she was going to outlive me.',
#  "absolute power\nmiss russell, i should've called the police that night but i was weak.",
#  'you convinced me to stay silent.',
#  'i regret that.',
#  'know this: every time i see your face, i wanna rip your throat out.',
#  'miss russell, i should have called the police that night.',
#  'but i was weak.',
#  'you convinced me to stay silent.',
#  'i regret that.',
#  'know this: every time i see your face i want to rip your throat out.',
#  'absolute power\nso, do you want my signed confession now, or after coffee?',
#  'so, do you want my confession now or after coffee?',
#  'ace ventura pet detective\nwarning.',
#  'assholes are closer than they appear.',
#  'warning!',
#  'assholes are closer than they appear!',
#  'the dog is barking insanely.',
#  'ace ventura pet detective\nyour gun is digging into my hip.',
#  "your gun's digging into my hip.",
#  'more kissing, the ace stops.',
#  'ace ventura pet detective\nbe careful with that phone, lieutenant.',
#  'in time you could develop a tumour.',
#  'be careful with that phone, lieutenant.',
#  "i wouldn't want you to get a tumor.",
#  "ace ventura pet detective\nif i'm not back in five minutes... just wait longer.",
#  "if i'm not back in five minutes\n call lloyd bridges.",
#  "ace ventura pet detective\nit was all that dan marino's fault, everyone knows that.",
#  'if he had held the ball, laces out, like he was supposed to, ray would never have missed that kick.',
#  'dan marino should die of gonorrhea and rot in hell.',
#  'would you like a cookie, son?',
#  "it was all that dan marino's fault, everyone knows that.",
#  "if he had held the ball laces out, like you're supposed to, ray would never have missed that kick.",
#  'dan marino should die of gonorrhea and rot in hell.',
#  'would you like a cookie, son?',
#  'ace takes a cookie.',
#  'holding it up.',
#  'ace ventura pet detective\ni need some refreshments, dan.',
#  'would you like some refreshments, dan?',
#  "i'll be right back, dan.",
#  'i made some refreshments, dan.',
#  'would you like some refreshments, dan?',
#  "i'll be right back, daaaan!!",
#  'she goes.',
#  'dan struggles, but to no avail.',
#  'ace ventura pet detective\nhey ventura, ventura.',
#  'make any good collars lately, or were they leashes.',
#  'hey, ventura!',
#  'make any good collars lately?',
#  'ace ventura pet detective\nwho let dr. dolittle in?',
#  'who let dr. doolittle in?',
#  'emilio steps in immediately.',
#  'ace ventura pet detective\nthat was a close one ladies and gentleman.',
#  'unfortunately in every contest, there must be a loser.',
#  'loo-hoo-ser-her.',
#  'that was a close one, ladies and gentlemen.',
#  'unfortunately, in every contest, there must be...\n\nace ventura pet detective\nuh oh, i think i heard a toilet flush.',
#  'maybe somebody lost a turtle.',
#  'uh oh, i think i heard a toilet flush.',
#  'maybe someone lost their turtle?',
#  'everyone has a laugh.',
#  'ace looks beaten.',
#  'ace ventura pet detective\npet detective:  howdy lurch.',
#  'ace ventura, pet detective.',
#  'excuse me, guy?!',
#  "my name is ace ventura, i'm a pet detective.",
#  "i'd like to ask you a few questions if i could.",
#  'no one even looks at him.',
#  'ace ventura pet detective\noh there is just one more thing lieutenant...\n oh, there is just one more thing, lieutenant.',
#  "this man is roger podacter's neighbor.",
#  'he lives across the hall.',
#  'he said he heard a scream, is that right, sir?',
#  'the neighbor nods.',
#  'ace turns to the apartment manager.',
#  'adaptation\nsee her?',
#  'i fucked her up the ass.',
#  'see her?',
#  'i fucked her up the ass.',
#  "adaptation\nlook, i'll tell you a story, all right?",
#  'i once feel deeply, you know, profoundly in love with tropical fish.',
#  'had  goddamn fish tanks in my house.',
#  'i skin dived to find just the right ones.',
#  'anisotremus virginicus, holdacanthus ciliaris, chaetodon capistratus.',
#  'you name it.',
#  'then one day i say, "fuck fish".',
#  'i renounce fish.',
#  'i vow never to set foot in that ocean again.',
#  'that\'s how much "fuck fish".',
#  "i'll tell you a story.",
#  'i once fell deeply, profoundly in love with tropical fish.',
#  'i had sixty goddamn fish tanks in my house.',
#  "i'd skin-dive to find just the right ones.",
#  'anisotremus virginicus, holacanthus ciliaris, chaetodon capistratus.',
#  'you name it.',
#  'then one day i say, fuck fish.',
#  'i renounce fish.',
#  'adaptation\ni suppose i do have one unembarrassed passion.',
#  'i want to know what it feels like to care about something passionately.',
#  "here's me!",
#  "here's me again!",
#  '"i wanted to know what it\'s like to care about something passionately."',
#  "adaptation\nokay, well here's the twist.",
#  'we find out that, that the killer really suffers from multiple personality disorder, right?',
#  "see, he's actually really the cop and the girl.",
#  'all of them are him.',
#  "isn't that fucked up?",
#  "okay, but there's a twist.",
#  'see, we find out the killer suffers from multiple personality disorder.',
#  'okay?',
#  "see, he's really also the cop and the girl.",
#  'all of them.',
#  "it's all him!",
#  "isn't that crazy?",
#  "adaptation\njohn leroche is a tall guy, skinny as a stick, pale eyes, slouch-shouldered, sharply handsome, despite the fact he's missing all his front teeth.",
#  'john laroche is a tall guy, skinny as a stick, pale-eyed, slouch-shouldered and sharply handsome despite the fact that he is missing all his front teeth.',
#  "adaptation\ni'd fuck her up the ass!",
#  'oh man.',
#  "i'd fuck her up the ass.",
#  'adaptation\nthere are too many ideas and things and people.',
#  'too many directions to go.',
#  'i was starting to believe the reason it matters to care passionately about something, is that it whittles the world down to a more manageable size.',
#  'there are too many ideas and things and people, too many directions to go.',
#  'i was starting to believe the reason it matters to care passionately about something is that it whittles the world down to a more manageable size.',
#  'adaptation\nyou and i share the same dna.',
#  'is there anything more lonely than that?',
#  'you and i share the same dna.',
#  'is there anything more lonely than that?',
#  'affliction\nyou will say that i should have known terrible things were about to happen.',
#  'you will say that i was responsible.',
#  'but even so, what could i have done by then?',
#  'wade lived on the edge of his emotions.',
#  "he was always first to receive the brunt of our father's anger.",
#  'he had no perspective to retreat to, even in a crisis.',
#  'you will say i should have known terrible things were about to happen, and perhaps i should have.',
#  'but even so, what could i have done by then?',
#  'wade never went inside.',
#  'he lived almost wholly out there on his skin, with no interior space to retreat to, even in a crisis.',
#  "affliction\nthis is the story of my older brother's strange criminal behaviour and disappearance.",
#  'we who loved him no longer speak of wade.',
#  "it's as if he never existed.",
#  "this is the story of my older brother's strange criminal behavior and disappearance.",
#  'we who loved him no longer speak of wade.',
#  "it's as if he never existed.",
#  'by telling his story like this, as his brother, i separate myself from his family and those who loved him.',
#  "everything of importance -- that is, everything that gives rise to the telling of this story -- occurred during a single deer-hunting season in a small town in upstate new hampshire where wade was raised and so was i. one night something changed and my relation to wade's story was different from what it had been since childhood.",
#  "i mark this change by wade's tone of voice during a phone call two nights after halloween.",
#  'something i had not heard before.',
#  "let us imagine that around eight o'clock on halloween eve, speeding past toby's, route , comes a pale green eight-year-old ford fairlane with a police bubble on top.",
#  "a square-faced man wearing a trooper's cap is driving the vehicle.",
#  'beside him sits a child, a little girl with a plastic tiger mask covering her face.',
#  "the man is driving fast --\n\naffliction\nnot a goddamn one of you is worth a hair on that good woman's head!",
#  "not a one of you is worth a goddamned hair on that good woman's head!",
#  "affliction\ni've got sons, goddamn it!",
#  'by god have i got sons!',
#  "i've got sons, goddamnit, oh my god, have i got sons!",
#  'wade?',
#  'rolfe?',
#  'elbourne?',
#  'you love me boys?',
#  'do you love your pop?',
#  'of course you do!',
#  "affliction\ni think there's some dirty business going on in this town.",
#  "alma, i think there's some dirty business going on in this town.",
#  'affliction\nchrist sally!',
#  'you are such a good person.',
#  'capital g!',
#  'by god you are... you are so much better than i am.',
#  'i am no goddamn good at all.',
#  'and you... you are truly a good person.',
#  'like a fucking saint!',
#  'oh, jesus, sally, you are such a goddamned good person!',
#  'capital g. you are so much better than i am, i who am no good at all, you who are a truly good person, like a fucking saint!',
#  'beyond fucking com-pare.',
#  'affliction\nyou know i get the feeling like a whipped dog some days.',
#  "some night i'm gonna bite back, i swear!",
#  "i get to feeling like a whipped dog some days, rolfe, and some night i'm going to bite back.",
#  'i swear it.',
#  "affliction\nyou know she won't be here for a half hour.",
#  'you think you can stand it here that long?',
#  "she won't be here for a half hour.",
#  'think you can stand it that long?',
#  "affliction\nthat's what i love about this small town.",
#  'everyone knows everyone.',
#  "that's what i love about a small town.",
#  'you know everybody.',
#  'after school special\nthe male deposits his seed, and moves on.',
#  'probably to a younger, more desirable female.',
#  "one who doesn't have any issues, whatever that means.",
#  'with one final thrust of his engorged penis, the male deposits his seed and moves on.',
#  'probably to a younger, more desirable female.',
#  'one who doesn\'t have any "issues."',
#  'whatever that means.',
#  'agnes of god\nas much as god loves you\n as much as god loves you.',
#  "agnes of god\ni don't know the meaning behind the song she sang.",
#  'perhaps it was a song of seduction, and the father was a field hand.',
#  'perhaps the song was simply a lullaby she remembered from many years ago, and the father was hope, and love, and desire and a belief in miracles.',
#  'i want to believe that she was blessed.',
#  'and i do miss her.',
#  "and i hope she's left something; some little part of herself with me.",
#  "that would be miracle enough, wouldn't it?",
#  "i don't know the meaning behind the song she sang.",
#  'perhaps it was a song of seduction.',
#  'and the father was a fieldhand.',
#  'perhaps the song was simply a lullaby that she remembered from many years ago.',
#  'and the father was hope and... and love and desire.',
#  'and a belief in miracles.',
#  'agnes of god\nas much as mother miriam loves me?',
#  'as much as mother miriam does?',
#  'air force one\nliberty two four is changing call signs - liberty two four is now air force one!',
#  "they've changed their bearing.",
#  'air force one.',
#  'air force one.',
#  'air force one\n.',
#  'no matter what happens, we land this aircraft is that understood?',
#  'no matter what happens, you have been and always will be my hero.',
#  'air force one\nmr. president, welcome aboard, sir!',
#  'welcome aboard, sir.',
#  'air force one\nhow the hell did they get air force one?',
#  'gentlemen, welcome to air force one.',
#  'airplane\nthe oil pressure.',
#  'i forgot to check the oil pressure!',
#  "when kramer hears about this, the shit's going to hit the fan!",
#  'oil pressure.',
#  'i forgot to check the oil pressure.',
#  "when kramer hears about this, the shit's gonna hit the fan.",
#  'airplane\ni know but this guy has no flying experience at all.',
#  "he's a menace to himself and everything else in the air... yes, birds too.",
#  'this guy doing the flying has no airline experience at all.',
#  "he'll be a menace to himself and everything else in the air... ...yes, birds too.",
#  'airplane\njoey, have you ever been in a... in a turkish prison?',
#  'joey, have you ever been in a turkish prison?',
#  'airplane\nshanna, they bought their tickets, they knew what they were getting into.',
#  "i say, let 'em crash.",
#  'shana, they bought their tickets, they knew what they were getting into.',
#  "i say, let 'em crash!",
#  'airplane\ni just want to tell you both good luck.',
#  "we're all counting on you.",
#  'i just wanted to tell you both good luck.',
#  "we're all counting on you.",
#  'airplane\nthe tower, the tower!',
#  'rapunzel, rapunzel!',
#  'the tower!',
#  'oh!',
#  'rapunzel!',
#  'rapunzel!',
#  "airplane\nwhere did you get that dress, it's awful, and those shoes and that coat, jeeeeez!",
#  'where did you get that dress?',
#  "it's an eye- sore!",
#  "airplane\nhe's all over the place!",
#  'nine hundred feet up to  feet.',
#  'what an asshole!',
#  "he's all over the place!",
#  'nine hundred feet up to thirteen hundred feet!',
#  'what an asshole!',
#  "airplane\ni haven't felt this awful since we saw that ronald reagan film.",
#  'my, stomach.',
#  "i haven't felt this awful since we saw that lina wertmuller film.",
#  "airplane\nno, we can't do that, the risk of a flame-out is too great.",
#  "keep 'em at ,.",
#  'no, feet.',
#  "no, we can't do that; the risk of a flameout is too great.",
#  'keep him ,.',
#  'no, feet!',
#  "airplane\nno wonder you're upset.",
#  "she's lovely.",
#  'and a darling figure... supple, pouting breasts... firm thighs.',
#  "it's a shame you two don't get along.",
#  "no wonder you're upset.",
#  "she's lovely.",
#  'and a darling figure.',
#  'supple, pouting breasts.',
#  'firm thighs.',
#  "it's a shame you're not getting along.",
#  "airplane\nwell, i'll give him another twenty minutes, but that's it!",
#  "well, i'll give him another twenty minutes, but that's it.",
#  "airplane\nthe life of everyone on board depends upon just one thing: finding someone back there who can not only fly this plane, but who didn't have fish for dinner.",
#  'i think you ought to know what our chances are.',
#  "the life of everyone on board depends on just one thing: finding someone back there who not only can fly this plane, but who didn't have fish for dinner.",
#  'airplane\nextremely serious.',
#  'it starts with a slight fever and dryness of the throat.',
#  'when the virus penetrates the red blood cells, the victim becomes dizzy, begins to experience an itchy rash, then the poison goes to work on the central nervous system, severe muscle spasms followed by the inevitable grueling.',
#  'at this point, the entire digestive system collapses accompanied by uncontrollable flatulence  until finally, the poor bastard is reduced to a quivering wasted piece of jelly.',
#  'then a dryness in the throat.',
#  'as the virus penetrates the red blood cells the victim becomes dizzy and begins to experience a rash and itching.',
#  'from there the poison works its way into the central nervous system causing severe muscle spasms, followed by the inevitable drooling.',
#  'at this point, the entire digestive system is rendered useless, causing the complete collapse of the lower bowels, accompanied by uncontrollable flatulence...until finally the poor bastard is reduced to a quivering, wasted piece of jelly.',
#  "airplane ii: the sequel\ni'm gonna go get ted, just don't fall apart on me now!",
#  "i've got to get ted.",
#  "just don't come apart on me now, simon.",
#  "aladdin\nwe just keep running into each other, don't we, street rat?",
#  "we just keep running into each other, don't we,\n\naladdin\nyou know al, i'm getting really -  i don't think you're him.",
#  'oh, al.',
#  "i'm gettin' kind of fond of you, kid.",
#  "not\n\naladdin\noooooh, nice shot, jafa-\n oh, nice shot, jaf--\n\naladdin\nyou've heard of the golden rule, haven't you?",
#  'whoever has the gold makes the rules.',
#  "you've heard of the golden rule, haven't you boy?",
#  'aladdin\nwho disturbs my slumber?',
#  'who disturbs my slumber?',
#  'aladdin\nladies and gentlemen, a warm agrabah welcome for sorceror jafar!',
#  'ladies and gentlemen, a warm agrabah welcome for\n\naladdin\nlook at that, abu.',
#  "it's not everyday you see a horse with two rear ends.",
#  'look at that, abu.',
#  "it's not every day you see a\n\naladdin\nyou're speechless, i see.",
#  'a fine quality in a wife.',
#  "you're speechless, i see.",
#  "a fine quality in a\n\naladdin\ni don't know where she gets it from.",
#  "her mother wasn't nearly so picky.",
#  "i don't know where she gets it from.",
#  'her mother\n\nali\ndon king talks black, lives white and thinks green.',
#  'don king talks black, lives white and thinks green!',
#  'why you defending him and "brother" herbert?',
#  "ali\nfloat like a butterfly, sting like a bee his hands can't hit what his eyes can't see.",
#  'float like a butterfly!',
#  'sting like a bee!',
#  'rumble, young man, rumble.',
#  'aaaaaaargh!',
#  "ali\nwhat's my name?",
#  "what's my name, motherfucker!",
#  "what's my name, motherfucker?!",
#  "ali\ni ain't draft dodging.",
#  "i ain't burning no flag.",
#  "i ain't running to canada.",
#  "i'm staying right here.",
#  'you want to send me to jail?',
#  'fine, you go right ahead.',
#  "i've been in jail for  years.",
#  "i could be there for  or  more, but i ain't going no , miles to help murder and kill other poor people.",
#  "if i want to die, i'll die right here, right now, fightin' you, if i want to die.",
#  'you my enemy, not no chinese, no vietcong, no japanese.',
#  'you my opposer when i want freedom.',
#  'you my opposer when i want justice.',
#  'you my opposer when i want equality.',
#  'want me to go somewhere and fight for you?',
#  "you won't even stand up for me right here in america, for my rights and my religious beliefs.",
#  "you won't even stand up for my right here at home.",
#  "i ain't draft dodgin'!",
#  "i ain't goin' to canada.",
#  "i ain't burnin' my draft card.",
#  "i ain't burnin' the flag.",
#  "i'm stayin' right here.",
#  'and you want to throw me in jail?',
#  'go ahead.',
#  "i'll do my time.",
#  'i been in jail four hundred years.',
#  "i'll be in jail four, five more.",
#  "but i ain't goin' ten thousand miles to help murder and kill poor people for you.",
#  "'cause if i'm gonna die, i'll die now, right here, fighting you.",
#  'if i wanna die.',
#  'you my enemy, not vietcong or chinese or japanese.',
#  'you my opposer when i want freedom.',
#  'you my opposer when i want justice.',
#  'you my opposer when i want equality.',
#  "you want me to go somewhere for you, but you won't even stand up for me in america, for my rights and beliefs, you won't even stand up for me here at home.",
#  "ali\ni'm the only normal one left around here.",
#  "i'm a black jew, i'm half drunk and i cant read.",
#  "man, i'm the only normal person left around here and i'm a black jew who can't read and is half drunk.",
#  "ali\nain't no vietcong ever called me nigger.",
#  'no vietcong ever called me nigger.',
#  'ali\nyou look like the heavyweight champion of pimps.',
#  '...what heavyweight champion of the world?',
#  "i'm not the champ.",
#  'i am retired, finished, out of the game.',
#  "and i ain't gonna let myself grieve and suffer none.",
#  "but i know i will not fight again...\n\nali\ni'm gonna give  dollars to the man who brings me howard cosell's toupee, dead or alive.",
#  "a thousand dollars to the man who brings me howard cosell's toupee!",
#  'dead or alive!',
#  'alien\ni found it.',
#  'just short of zeta ii reticuli.',
#  "we haven't reached the outer rim yet.",
#  'just short of zeta ii reticuli.',
#  "we haven't even reached the outer rim yet.",
#  'alien\nthis is commercial towing vehicle nostromo out of the solomons, registration number ---niner-----niner.',
#  'calling antarctica traffic control.',
#  'do you read me?',
#  'over.',
#  'this is deep space commercial vessel snark, registration number e, calling antarctica air traffic control.',
#  'do you read me?',
#  'over.',
#  'alien nation\nyour mother mates out of season.',
#  'your mother mates out of season.',
#  'alien nation\nif the drug is here, we must destroy it!',
#  'if the drug is here, we must destroy it.',
#  'alien nation\nit is like your name... sykes.',
#  'i\'m sure it doesn\'t bother you at all that it sounds like "ss\'ai k\'ss," two words in my language which mean "excrement" and "cranium."',
#  'shithead.',
#  'that is exactly so.',
#  'it is like your name... sykes.',
#  'i\'m sure it doesn\'t bother you at all that it sounds like "ss\'ai k\'ss", two words in my language which mean "excrement" and "cranium".',
#  "alien resurrection\nfather's dead, asshole.",
#  'intruder on level one.',
#  'all aliens, please proceed to level one.',
#  'intruder on level one... all aliens please proceed to level one.',
#  'alien resurrection\nyou are... a beautiful, beautiful, butterfly.',
#  "beautiful.... beautiful butterfly...\n\nalien resurrection\nshe is severely fuckable, ain't she?",
#  "she is severely fuckable, isn't she?",
#  '- and the very devil with a socket wrench.',
#  "alien resurrection\ndon't push me, little call.",
#  "you hang with us for a while, you'll find out i am not the man with whom to fuck!",
#  "don't push me, little annalee.",
#  "you hang with us a while, you'll learn i'm not the man with whom to fuck.",
#  "alien resurrection\ndon't ever touch me!",
#  'ever!',
#  "don't touch me.",
#  "alien resurrection\nyou're a thing, a construct.",
#  'they grew you in a fucking lab.',
#  "you're a thing.",
#  'a construct.',
#  'they grew you in a fucking lab.',
#  'alien resurrection\nmy mommy always said there were no monsters.',
#  'no real ones.',
#  'but there are.',
#  'my mom always said there were no monsters -- no, real ones -- but there are.',
#  'alien resurrection\nhey christie, do me a favour.',
#  'when we hit the surface on the other side, no backstroke, okay!',
#  'christie, do me a favor.',
#  'when we hit the surface on the other side... no backstroke.',
#  'okay?',
#  "aliens\nwe'd better get back, 'cause it'll be dark soon, and they mostly come at night... mostly.",
#  "we should get back, 'cause it'll be dark soon.",
#  'they come mostly at night.',
#  'mostly.',
#  ...]

# %%
word_tokens
# Out:
# ['things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'who',
#  'knocked',
#  'up',
#  'your',
#  'sister',
#  '?',
#  'who',
#  'knocked',
#  'up',
#  'your',
#  'sister',
#  '?',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'i',
#  'was',
#  'watching',
#  'you',
#  'out',
#  'there',
#  ',',
#  'before',
#  '.',
#  'i',
#  "'ve",
#  'never',
#  'seen',
#  'you',
#  'look',
#  'so',
#  'sexy',
#  '.',
#  'i',
#  'watched',
#  'you',
#  'out',
#  'there',
#  'i',
#  "'ve",
#  'never',
#  'seen',
#  'you',
#  'look',
#  'like',
#  'that',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'you',
#  "'re",
#  ',',
#  'you',
#  'do',
#  "n't",
#  'know',
#  'what',
#  'you',
#  'want',
#  '.',
#  'and',
#  'you',
#  'wo',
#  "n't",
#  'know',
#  'what',
#  'you',
#  'want',
#  "'til",
#  'you',
#  "'re",
#  ',',
#  'and',
#  'even',
#  'if',
#  'you',
#  'get',
#  'it',
#  ',',
#  'you',
#  "'ll",
#  'be',
#  'too',
#  'old',
#  'to',
#  'use',
#  'it',
#  '.',
#  'you',
#  "'re",
#  'eighteen',
#  '.',
#  'you',
#  'do',
#  "n't",
#  'know',
#  'what',
#  'you',
#  'want',
#  '.',
#  'you',
#  'wo',
#  "n't",
#  'know',
#  'until',
#  'you',
#  "'re",
#  'forty-five',
#  'and',
#  'you',
#  'do',
#  "n't",
#  'have',
#  'it',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'ooh',
#  ',',
#  'see',
#  'that',
#  ',',
#  'there',
#  '.',
#  'who',
#  'needs',
#  'affection',
#  'when',
#  'i',
#  'have',
#  'blind',
#  'hatred',
#  '?',
#  'see',
#  'that',
#  '?',
#  'who',
#  'needs',
#  'affection',
#  'when',
#  'i',
#  "'ve",
#  'got',
#  'blind',
#  'hatred',
#  '?',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'just',
#  "'cause",
#  'you',
#  "'re",
#  'beautiful',
#  ',',
#  'that',
#  'does',
#  "n't",
#  'mean',
#  'that',
#  'you',
#  'can',
#  'treat',
#  'people',
#  'like',
#  'they',
#  'do',
#  "n't",
#  'matter',
#  '.',
#  'just',
#  'because',
#  'you',
#  "'re",
#  'beautiful',
#  ',',
#  'does',
#  "n't",
#  'mean',
#  'you',
#  'can',
#  'treat',
#  'people',
#  'like',
#  'they',
#  'do',
#  "n't",
#  'matter',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'you',
#  "'re",
#  'asking',
#  'me',
#  'out',
#  '?',
#  'that',
#  "'s",
#  'so',
#  'cute',
#  '!',
#  'what',
#  "'s",
#  'your',
#  'name',
#  'again',
#  '?',
#  'you',
#  "'re",
#  'asking',
#  'me',
#  'out',
#  '.',
#  'that',
#  "'s",
#  'so',
#  'cute',
#  '.',
#  'what',
#  "'s",
#  'your',
#  'name',
#  'again',
#  '?',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'leave',
#  'it',
#  'to',
#  'you',
#  'to',
#  'use',
#  'big',
#  'words',
#  'when',
#  'you',
#  "'re",
#  'smashed',
#  '.',
#  'leave',
#  'it',
#  'to',
#  'you',
#  'to',
#  'use',
#  'big',
#  'words',
#  'when',
#  'you',
#  "'re",
#  'shitfaced',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'and',
#  'i',
#  "'m",
#  'back',
#  'in',
#  'the',
#  'game',
#  '!',
#  'and',
#  'i',
#  "'m",
#  'back',
#  'in',
#  'the',
#  'saddle',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'i',
#  'guess',
#  'in',
#  'this',
#  'society',
#  ',',
#  'being',
#  'male',
#  'and',
#  'an',
#  'asshole',
#  'makes',
#  'you',
#  'worthy',
#  'of',
#  'our',
#  'time',
#  '.',
#  'i',
#  'guess',
#  'the',
#  'school',
#  'board',
#  'thinks',
#  'because',
#  'hemingway',
#  "'s",
#  'male',
#  'and',
#  'an',
#  'asshole',
#  ',',
#  'he',
#  "'s",
#  'worthy',
#  'of',
#  'our',
#  'time',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'i',
#  'have',
#  'a',
#  'dick',
#  'on',
#  'my',
#  'face',
#  ',',
#  'do',
#  "n't",
#  'i',
#  '?',
#  'i',
#  'have',
#  'a',
#  'dick',
#  'on',
#  'my',
#  'face',
#  ',',
#  'do',
#  "n't",
#  'i',
#  '?',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'you',
#  'embarrassed',
#  'the',
#  'girl',
#  '.',
#  'sacrifice',
#  'yourself',
#  'on',
#  'the',
#  'alter',
#  'of',
#  'dignity',
#  'and',
#  'even',
#  'the',
#  'score',
#  '.',
#  'you',
#  'humiliated',
#  'the',
#  'woman',
#  '!',
#  'sacrifice',
#  'yourself',
#  'on',
#  'the',
#  'altar',
#  'of',
#  'dignity',
#  'and',
#  'even',
#  'the',
#  'score',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'you',
#  "'re",
#  'not',
#  'as',
#  'vile',
#  'as',
#  'i',
#  'thought',
#  'you',
#  'were',
#  '.',
#  'you',
#  'know',
#  '--',
#  'you',
#  "'re",
#  'not',
#  'as',
#  'vile',
#  'as',
#  'i',
#  'thought',
#  'you',
#  'were',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'it',
#  "'s",
#  'not',
#  'everyday',
#  'you',
#  'find',
#  'a',
#  'girl',
#  'who',
#  "'ll",
#  'flash',
#  'someone',
#  'to',
#  'get',
#  'you',
#  'out',
#  'of',
#  'detention',
#  '.',
#  'you',
#  'know',
#  '--',
#  'it',
#  "'s",
#  'not',
#  'every',
#  'day',
#  'you',
#  'find',
#  'a',
#  'girl',
#  'who',
#  "'ll",
#  'flash',
#  'her',
#  'tits',
#  'to',
#  'get',
#  'you',
#  'out',
#  'of',
#  'detention',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'watching',
#  'that',
#  'bitch',
#  'violate',
#  'my',
#  'car',
#  'does',
#  "n't",
#  'count',
#  'as',
#  'a',
#  'date',
#  '.',
#  'watching',
#  'the',
#  'bitch',
#  'trash',
#  'my',
#  'car',
#  'does',
#  "n't",
#  'count',
#  'as',
#  'a',
#  'date',
#  '.',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'oh',
#  'wait',
#  '...',
#  'was',
#  'that',
#  '...',
#  'did',
#  'your',
#  'hairline',
#  'just',
#  'recede',
#  '?',
#  'wait',
#  '--',
#  'was',
#  'that',
#  '?',
#  '--',
#  'did',
#  'your',
#  'hairline',
#  'just',
#  'recede',
#  '?',
#  'things',
#  'i',
#  'hate',
#  'about',
#  'you',
#  'remove',
#  'head',
#  'from',
#  'sphincter',
#  ',',
#  'then',
#  'drive',
#  '!',
#  'remove',
#  'head',
#  'from',
#  'sphincter',
#  '!',
#  'then',
#  'pedal',
#  '!',
#  ':',
#  'conquest',
#  'of',
#  'paradise',
#  'of',
#  'all',
#  'the',
#  'words',
#  'my',
#  'father',
#  'wrote',
#  '-',
#  'and',
#  'there',
#  'were',
#  'many',
#  '-',
#  'i',
#  'remember',
#  'these',
#  'the',
#  'most',
#  ':',
#  '``',
#  'nothing',
#  'that',
#  'results',
#  'from',
#  'human',
#  'progress',
#  'is',
#  'achieved',
#  'with',
#  'unanimous',
#  'consent',
#  '.',
#  'and',
#  'those',
#  'who',
#  'are',
#  'enlightened',
#  'before',
#  'the',
#  'others',
#  'are',
#  'condemned',
#  'to',
#  'persue',
#  'that',
#  'light',
#  'in',
#  'spite',
#  'of',
#  'others',
#  '.',
#  "''",
#  'of',
#  'all',
#  'the',
#  'words',
#  'my',
#  'father',
#  'wrote',
#  'and',
#  'there',
#  'were',
#  'many',
#  ',',
#  'i',
#  'remember',
#  'these',
#  'the',
#  'most',
#  '.',
#  '``',
#  'nothing',
#  'that',
#  'results',
#  'from',
#  'human',
#  'progress',
#  'is',
#  'achieved',
#  'with',
#  'unanimous',
#  'consent',
#  '...',
#  "''",
#  'minutes',
#  'i',
#  'can',
#  'kill',
#  'you',
#  '-',
#  'i',
#  "'m",
#  'insane',
#  '.',
#  'be',
#  'careful',
#  '.',
#  'i',
#  'can',
#  'kill',
#  'you',
#  '.',
#  'i',
#  "'m",
#  'insane',
#  '.',
#  'minutes',
#  'i',
#  'love',
#  'america',
#  '.',
#  'no',
#  'one',
#  'is',
#  'responsible',
#  'for',
#  'what',
#  'they',
#  'do',
#  '.',
#  'i',
#  'love',
#  'america',
#  '.',
#  'no',
#  'one',
#  'is',
#  'responsible',
#  'for',
#  'what',
#  'they',
#  'do',
#  '.',
#  ':',
#  'a',
#  'space',
#  'odyssey',
#  'welcome',
#  'to',
#  'voiceprint',
#  'identification',
#  '.',
#  'when',
#  'you',
#  'see',
#  'the',
#  'red',
#  'light',
#  'go',
#  'on',
#  ',',
#  'would',
#  'you',
#  'please',
#  'state',
#  'in',
#  'the',
#  'following',
#  'order',
#  ':',
#  'your',
#  'destination',
#  ',',
#  'your',
#  'nationality',
#  ',',
#  'and',
#  'your',
#  'full',
#  'name',
#  ';',
#  'surname',
#  'first',
#  ',',
#  'christian',
#  'name',
#  'and',
#  'initial',
#  '.',
#  'good',
#  'morning',
#  'and',
#  'welcome',
#  'to',
#  'voice',
#  'print',
#  'identification',
#  '.',
#  'when',
#  'you',
#  'see',
#  'the',
#  'red',
#  'light',
#  'go',
#  'on',
#  'would',
#  'you',
#  'please',
#  'state',
#  'in',
#  'the',
#  'following',
#  'order',
#  ';',
#  'your',
#  'desitination',
#  ',',
#  'your',
#  'nationality',
#  'and',
#  'your',
#  'full',
#  'name',
#  '.',
#  'surname',
#  'first',
#  ',',
#  'christian',
#  'name',
#  'and',
#  'initial',
#  '.',
#  'for',
#  'example',
#  ':',
#  'moon',
#  ',',
#  'american',
#  ',',
#  'smith',
#  ',',
#  'john',
#  ',',
#  'd.',
#  'thank',
#  'you',
#  '.',
#  'mm',
#  'starlight',
#  ';',
#  'star',
#  'bright',
#  ',',
#  'first',
#  'star',
#  'i',
#  "'ve",
#  'seen',
#  'tonight',
#  ',',
#  'i',
#  'wish',
#  'i',
#  'may',
#  ';',
#  'i',
#  'wish',
#  'i',
#  'might',
#  ',',
#  'have',
#  'this',
#  'wish',
#  'i',
#  'wish',
#  'tonight',
#  '``',
#  'star',
#  'light',
#  ',',
#  'star',
#  'bright',
#  ',',
#  'first',
#  'star',
#  'i',
#  "'ve",
#  'seen',
#  'tonight',
#  ',',
#  'wish',
#  'i',
#  'may',
#  ',',
#  'wish',
#  'i',
#  'might',
#  ',',
#  'have',
#  'this',
#  'wish',
#  'i',
#  'wish',
#  'tonight',
#  '.',
#  "''",
#  'mm',
#  'oh',
#  ',',
#  'he',
#  "'s",
#  'a',
#  'lover',
#  ',',
#  'man',
#  '...',
#  'definitely',
#  'loves',
#  'what',
#  'he',
#  'does',
#  'for',
#  'a',
#  'living',
#  '.',
#  'he',
#  "'s",
#  'a',
#  'brutal',
#  'motherfucker',
#  ',',
#  'man',
#  '.',
#  'he',
#  'loves',
#  'what',
#  'he',
#  'does',
#  'for',
#  'a',
#  'living',
#  '.',
#  'a',
#  'bucket',
#  'of',
#  'blood',
#  'i',
#  'did',
#  "n't",
#  'mean',
#  'to',
#  'hurt',
#  'you',
#  ',',
#  'lou',
#  '.',
#  'but',
#  'if',
#  'you',
#  "'d",
#  'have',
#  'shot',
#  'me',
#  ',',
#  'you',
#  "'d",
#  'be',
#  'moppin',
#  "'",
#  'up',
#  'my',
#  'blood',
#  'now',
#  '.',
#  'i',
#  'did',
#  "n't",
#  'mean',
#  'to',
#  'hurt',
#  'you',
#  ',',
#  'sir',
#  '...',
#  'if',
#  'you',
#  'had',
#  'shot',
#  'me',
#  ',',
#  'you',
#  "'d",
#  'be',
#  'mopping',
#  'up',
#  'my',
#  'blood',
#  'now',
#  '...',
#  'a',
#  'bucket',
#  'of',
#  'blood',
#  'where',
#  'are',
#  'john',
#  ',',
#  'joe',
#  ',',
#  'jake',
#  ',',
#  'jim',
#  ',',
#  'jerk',
#  '?',
#  'dead',
#  ',',
#  'dead',
#  ',',
#  'dead',
#  '!',
#  'they',
#  'were',
#  'not',
#  'born',
#  ',',
#  'before',
#  'they',
#  'were',
#  'born',
#  ',',
#  'they',
#  'were',
#  'not',
#  'born',
#  '.',
#  'where',
#  'are',
#  'leonardo',
#  ',',
#  'rembrandt',
#  ...]

# %% [markdown]
# #### Functions to convert text to tokens
# Next, we have a few functions to lemmanize our tokens:

# %%
lemmer = nltk.stem.WordNetLemmatizer()

def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]

remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)

def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))

# %% [markdown]
# #### Initial greeting
#
# Now, let us setup our initial greeting from a defined list:

# %%
GREETING_INPUTS = ("hello", "hi", "greetings", "sup", "what's up","hey",)
GREETING_RESPONSES = ["hi", "hey", "*nods*", "hi there", "hello", "I am glad! You are talking to me"]

def greeting(sentence):
 
    for word in sentence.split():
        if word.lower() in GREETING_INPUTS:
            return random.choice(GREETING_RESPONSES)

# %% [markdown]
# #### List of stopwords
#
# And let us shore up our list of stopwords from the default:

# %%
stopwords = stopwords.words('english')

additional_stop_words = ['arent', 'couldnt', 'didnt', 'doe', 'doesnt', 'dont', 'ha', 'hadnt', 'hasnt', 'havent', 'isnt', 'mightnt', 'mustnt', 'neednt', 'shant', 'shes', 'shouldnt', 'shouldve', 'thatll', 'wa', 'wasnt', 'werent', 'wont', 'wouldnt', 'youd', 'youll', 'youre', 'youve']

for word in additional_stop_words:
    stopwords.append(word)

# %% [markdown]
# #### Build our reponse engine
#
# Our response engine function will take in a user's response, create a text vector using our vocabulary of known words, and do a similarity test to identify the best response:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.metrics.pairwise import cosine_similarity

# %%
def response(user_response):
    robo_response=''
    sent_tokens.append(user_response)
    TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words=stopwords)
    tfidf = TfidfVec.fit_transform(sent_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx=vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
    if(req_tfidf==0):
        robo_response=robo_response+"I am sorry! I don't understand you"
        return robo_response
    else:
        robo_response = robo_response+sent_tokens[idx]
        return robo_response

# %% [markdown]
# #### Run the chatbot
#
# Now we run the chatbot using a loop:

# %%
flag=True
print("ROBO: My name is Robo. I will answer your queries about Chatbots. If you want to exit, type Bye!")
while(flag==True):
    user_response = input()
    user_response=user_response.lower()
    if(user_response!='bye'):
        if(user_response=='thanks' or user_response=='thank you' ):
            flag=False
            print("ROBO: You are welcome..")
        else:
            if(greeting(user_response)!=None):
                print("ROBO: "+greeting(user_response))
            else:
                print("ROBO: ",end="")
                print(response(user_response))
                sent_tokens.remove(user_response)
    else:
        flag=False
        print("ROBO: Bye! take care..")
# Out:
# ROBO: My name is Robo. I will answer your queries about Chatbots. If you want to exit, type Bye!
# Hi
# ROBO: hey
# how you doing?
# ROBO: I am sorry! I don't understand you
# I would like to take a walk
# ROBO: we would take long walks by the river.
# bye
# ROBO: Bye! take care..
